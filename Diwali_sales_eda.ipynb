# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"D:\ANURAG\python\Pandas\Download for Pandas\Diwali Sales Data.csv")

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# df.drop(columns=['Status', 'unnamed1'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
# Change data type

df['Amount'] = df['Amount'].astype('int')

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610858
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610858
# std       12.753866      1.114967   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Draw a chart for Gender wise order count
# ax = sns.countplot(x = 'Gender', data = df, palette = 'Set2')

ax = sns.countplot(
    x='Gender',
    data=df,
    palette=['Pink', 'Lightblue'])   # Here we can change color to our preference


for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\799914495.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %%
df.groupby(['Gender'],as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# Out:
#   Gender       Amount
# 0      F  74335856.43
# 1      M  31913276.00

# %%
# Gender wise sales

sales_gen = df.groupby(['Gender'],as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y = 'Amount', data = sales_gen, palette = 'Set2')
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\537181264.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Gender',y = 'Amount', data = sales_gen, palette = 'Set2')
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# From the above graph, we can say that purchasing power of FEMALE is far more than MALES

# %% [markdown]
# # AGE

# %%
ax = sns.countplot(x = 'Age Group', data = df, hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group

sales_age = df.groupby(['Age Group'],as_index = False).sum().sort_values(by = 'Amount', ascending = False )

sales_age
# Out:
#   Age Group     User_ID                                          Cust_name  \
# 2     26-35  4557104976  SanskritiKartikBinduJoniJoniKushalGinnyHarshit...
# 3     36-45  2292804483  GibsonJamesMousamEllisonStewartElizabethChampa...
# 1     18-25  1884305684  BalkKargatisElijahLaurenEllisMahimaDeanSwetaDe...
# 4     46-50   990011756  CanoAmyHrisheekeshEugeneJackO'BrianCharlotteAk...
# 5     51-55   834514507  PraneetPraneetGilcrestEtezadiDanielsVineetPati...
# 6       55+   429277006  ShivangiSkariaMikeBrittainMartinezDodsonMcClur...
# 0      0-17   296785084  SudeviZypernLynnPhanPhanCaffeyJoyTalbottSteven...
#
#                                           Product_ID  \
# 2  P00125942P00110942P00118542P00057942P00057942P...
# 3  P00234742P00119642P00220042P0096942P00036242P0...
# 1  P00018042P00119142P00080342P00289942P00180642P...
# 4  P00293742P00275642P00181842P00339042P00248442P...
# 5  P00029842P00029842P00271842P00190542P00080042P...
# ...

# %%
sns.barplot(x = 'Age Group', y = 'Amount', data = sales_age, palette='Set2')
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\2904036109.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Age Group', y = 'Amount', data = sales_age, palette='Set2')
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# This graph shows that most of the buyers are Female mostly in age group of: 26-35

# %% [markdown]
# # --> STATE

# %%
sales_state = df.groupby(['State'], as_index = False).sum().sort_values(by='Orders', ascending = False).head(10)

sales_state
# Out:
#                State     User_ID  \
# 14     Uttar Pradesh  1951746238
# 10       Maharashtra  1530622822
# 7          Karnataka  1308891597
# 2              Delhi  1110458130
# 9     Madhya Pradesh   925850171
# 0     Andhra Pradesh   814450215
# 5   Himachal Pradesh   609750920
# 8             Kerala   454335141
# 4            Haryana   453372900
# 3            Gujarat   430281777
#
#                                             Cust_name  \
# 14  BinduBalkKushalPraneetPraneetHrisheekeshGilcre...
# 10  SanskritiShivangiDamalaThaisBruceKeshavPatrick...
# 7   SudeviSkariaSujayVictorShamiO'BrianCharlotteLi...
# 2   HarshitaSwetaJesslynEugeneIshitSchwarzSmritiCh...
# 9   CanoBhosaleHaushalterKotsonisBenBethHemantBerg...
# 0   KartikGinnyKargatisElijahVasudevLaurenAmyMickE...
# 5   JoniMikeConnellMcCrossinEricaWardleSeioAkshata...
# 8   NeolaCyraVernonAnanyaLanierSukrithEllistonBeck...
# 4   ShivaniMuskanCariTraftonMurdockCollisterSinkGo...
# ...

# %%
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders', palette='Set1')
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\1870815366.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'State',y= 'Orders', palette='Set1')
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount', palette = 'Set2')
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\1540617272.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'State',y= 'Amount', palette = 'Set2')
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# # Marital Status

# %%
ax = sns.countplot(data = df, x = 'Marital_Status', palette = 'Set1')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\4054886615.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Marital_Status', palette = 'Set1')

# %%
sales_state = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# # OCCUPATION

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation',palette='Spectral')

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\776339450.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Occupation',palette='Spectral')

# %%
sales_state = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount',palette='tab20')
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\3564865711.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount',palette='tab20')
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector

# %% [markdown]
# # Product Category

# %% [markdown]
# ##

# %%
sns.set(rc={'figure.figsize':(25,8)})
ax = sns.countplot(data = df, x = 'Product_Category',palette='tab20' )

for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\609635756.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data = df, x = 'Product_Category',palette='tab20' )

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount' ,palette='tab20')
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\3026918375.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount' ,palette='tab20')
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders' ,palette='tab20')
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_20572\1046683219.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders' ,palette='tab20')
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,5))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
